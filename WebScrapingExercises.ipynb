# %% [markdown]
# ## Web Scraping
#
# Write a Python program that uses BeautifulSoup to go to https://news.google.com and prints out all of the headlines on the page. Then, write a function called find_headline_by_keyword which lets you search through those headlines for keywords, and returns to you a list of all of the headlines that match all the keywords you provide.

# %%
# !pip install zorba
# Out:
# ERROR: Could not find a version that satisfies the requirement zorba
# ERROR: No matching distribution found for zorba
# WARNING: You are using pip version 20.3.3; however, version 21.0 is available.
# You should consider upgrading via the 'c:\users\sabari vijay\anaconda3\python.exe -m pip install --upgrade pip' command.

# %%
import requests

# %%
import bs4

# %%
res = requests.get(" https://news.google.com")

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')

# %%
soup
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head><base href="https://news.google.com/"/><meta content="origin" name="referrer"/><link href="https://news.google.com/topstories" rel="canonical"/><meta content="width=device-width,initial-scale=1,minimal-ui" name="viewport"/><meta content="AcBy5YFny2HQgVUCR18tO5YUTf6MpVlcJqGTd-a9-SI" name="google-site-verification"/><meta content="yes" name="mobile-web-app-capable"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="News" name="application-name"/><meta content="News" name="apple-mobile-web-app-title"/><meta content="black" name="apple-mobile-web-app-status-bar-style"/><meta content="white" name="theme-color"/><meta content="no" name="msapplication-tap-highlight"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w16" rel="shortcut icon" sizes="16x16"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w24" rel="shortcut icon" sizes="24x24"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w32" rel="shortcut icon" sizes="32x32"/><link href="https://lh3.googleusercontent.com/-DR60l-K8vnyi99NZovm9HlXyZwQ85GMDxiwJWzoasZYCUrPuUM_P_4Rb7ei03j-0nRs0c4F=w48" rel="shortcut icon" sizes="48x48"/><link href="//www.gstatic.com" rel="preconnect"/><link href="//fonts.gstatic.com" rel="preconnect"/><link href="//lh3.googleusercontent.com" rel="preconnect"/><link href="//lh4.googleusercontent.com" rel="preconnect"/><link href="//lh5.googleusercontent.com" rel="preconnect"/><link href="//lh6.googleusercontent.com" rel="preconnect"/><link href="//ssl.gstatic.com" rel="preconnect"/><link href="//maps.googleapis.com" rel="preconnect"/><link href="https://www.google-analytics.com/analytics.js" rel="preconnect"/><link crossorigin="use-credentials" href="_/DotsSplashUi/manifest.json" rel="manifest"/><link href="/?lfhs=2" rel="home"/><link href="/?lfhs=2" rel="msapplication-starturl"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="icon" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="apple-touch-icon-precomposed" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_192.png" rel="msapplication-square192x192logo" sizes="192x192"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="icon" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="apple-touch-icon-precomposed" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_512.png" rel="msapplication-square512x512logo" sizes="512x512"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="icon" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="apple-touch-icon-precomposed" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_1024.png" rel="msapplication-square1024x1024logo" sizes="1024x1024"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="icon" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="apple-touch-icon-precomposed" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_120.png" rel="msapplication-square120x120logo" sizes="120x120"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="icon" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="apple-touch-icon-precomposed" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_152.png" rel="msapplication-square152x152logo" sizes="152x152"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="icon" sizes="167x167"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="apple-touch-icon-precomposed" sizes="167x167"/><link href="//ssl.gstatic.com/gnews/logo/google_news_167.png" rel="msapplication-square167x167logo" sizes="167x167"/><link href="//s ...
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# 'use strict';var a=window,d=a.performance,l=k();a.cc_latency_start_time=d&&d.now?0:d&&d.timing&&d.timing.navigationStart?d.timing.navigationStart:l;function k(){return d&&d.now?d.now():(new Date).getTime()}function n(f){if(d&&d.now&&d.mark){var h=d.mark(f);if(h)return h.startTime;if(d.getEntriesByName&&(f=d.getEntriesByName(f).pop()))return f.startTime}return k()}a.onaft=function(){n("aft");a.isPreloadSupported&&a.executeBaseJs()};
# a._isLazyImage=function(f){return f.hasAttribute("data-src")||f.hasAttribute("data-ils")||"lazy"===f.getAttribute("loading")};
# a.l=function(f){function h(b){var c={};c[b]=k();a.cc_latency.push(c)}function m(b){var c=n("iml");b.setAttribute("data-iml",c);return c}a.cc_aid=f;a.iml_start=a.cc_latency_start_time;a.css_size=0;a.cc_latency=[];a.ccTick=h;a.onJsLoad=function(){h("jsl")};a.onCssLoad=function(){h("cssl")};a._isVisible=function(b,c,g){g=void 0===g?!1:g;if(!c||"none"==c.style.display)return!1;var e=b.defaultView;if(e&&e.getComputedStyle&&(e=e.getComputedStyle(c),"0px"==e.height||"0px"==e.width||"hidden"==e.visibility&&
# !g))return!1;if(!c.getBoundingClientRect)return!0;e=c.getBoundingClientRect();c=e.left+a.pageXOffset;g=e.top+a.pageYOffset;if(0>g+e.height||0>c+e.width||0>=e.height||0>=e.width)return!1;b=b.documentElement;return g<=(a.innerHeight||b.clientHeight)&&c<=(a.innerWidth||b.clientWidth)};a._recordImlEl=m;document.documentElement.addEventListener("load",function(b){b=b.target;var c;"IMG"!=b.tagName||b.hasAttribute("data-iid")||a._isLazyImage(b)||b.hasAttribute("data-noaft")||(c=m(b));if(a.aft_counter&&(b=
# a.aft_counter.indexOf(b),-1!==b&&(b=1===a.aft_counter.splice(b,1).length,0===a.aft_counter.length&&b&&c)))a.onaft(c)},!0);a.prt=-1;a.wiz_tick=function(){var b=n("prt");a.prt=b}};}).call(this);
# l('p6ICWe')</script><script nonce="V1E+fRepipsOFwM6k5TCZA">var _F_cssRowKey = 'boq-dots.DotsSplashUi.DYtAbKKZaTE.L.W.O';var _F_combinedSignature = 'ALs0n2N9SK7gxNTP9biRtLxcW_Na6ud6HQ';function _DumpException(e) {throw e;}</script><style data-href="https://www.gstatic.com/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi.DYtAbKKZaTE.L.W.O/am=RAHfKAACAg/d=1/ed=1/ct=zgms/rs=ALs0n2N3oxHFgh4buBOeiaAOimVlGiUXgQ/m=topstories,_b,_tp" nonce="V1E+fRepipsOFwM6k5TCZA">html{height:100%;overflow:hidden}body{height:100%;overflow:hidden;-webkit-font-smoothing:antialiased;color:rgba(0,0,0,0.87);font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif;margin:0;-webkit-text-size-adjust:100%;-webkit-text-size-adjust:100%;text-size-adjust:100%}textarea{font-family:Roboto,RobotoDraft,Helvetica,Arial,sans-serif}a{text-decoration:none;color:#2962ff}img{border:none}*{-webkit-tap-highlight-color:transparent}#apps-debug-tracers{display:none}html{overflow:visible}body{overflow:visible;overflow-y:scroll}@keyframes mdc-ripple-fg-radius-in{0%{-webkit-animation-timing-function:cubic-bezier(0.4,0,0.2,1);animation-timing-function:cubic-bezier(0.4,0,0.2,1);-webkit-transform:translate(var(--mdc-ripple-fg-translate-start,0)) scale(1);transform:translate(var(--mdc-ripple-fg-translate-start,0)) scale(1)}to{-webkit-transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1));transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1))}}@keyframes mdc-ripple-fg-opacity-in{0%{-webkit-animation-timing-function:linear;animation-timing-function:linear;opacity:0}to{opacity:var(--mdc-ripple-fg-opacity,0)}}@keyframes mdc-ripple-fg-opacity-out{0%{-webkit-animation-timing-function:linear;animation-timing-function:linear;opacity:var(--mdc-ripple-fg-opacity,0)}to{opacity:0}}.VfPpkd-ksKsZd-XxIAqe{--mdc-ripple-fg-size:0;--mdc-ripple-left:0;--mdc-ripple-top:0;--mdc-ripple-fg-scale:1;--mdc-ripple-fg-translate-end:0;--mdc-ripple-fg-translate-start:0;-webkit-tap-highlight-color:rgba(0,0,0,0);will-change:transform,opacity;position:relative;outline:none;overflow:hidden}.VfPpkd-ksKsZd-XxIAqe::before{position:absolute;-webkit-border-radius:50%;border-radius:50%;opacity:0;pointer-events:none;content:""}.VfPpkd-ksKsZd-XxIAqe::after{position:absolute;-webkit-border-radius:50%;border-radius:50%;opacity:0;pointer-events:none;content:""}.VfPpkd-ksKsZd-XxIAqe::before{-webkit-transition:opacity 15ms linear,background-color 15ms linear;transition:opacity 15ms linear,background-color 15ms linear;z-index:1;z-index:var(--mdc-ripple-z-index,1)}.VfPpkd-ksKsZd-XxIAqe::after{z-index:0;z-index:var(--mdc-ripple-z-index,0)}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d::before{-webkit-transform:scale(var(--mdc-ripple-fg-scale,1));transform:scale(var(--mdc-ripple-fg-scale,1))}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d::after{top:0;left:0;-webkit-transform:scale(0);transform:scale(0);-webkit-transform-origin:center center;transform-origin:center center}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d-OWXEXe-ZNMTqd::after{top:var(--mdc-ripple-top,0);left:var(--mdc-ripple-left,0)}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d-OWXEXe-Tv8l5d-lJfZMc::after{-webkit-animation:mdc-ripple-fg-radius-in 225ms forwards,mdc-ripple-fg-opacity-in 75ms forwards;animation:mdc-ripple-fg-radius-in 225ms forwards,mdc-ripple-fg-opacity-in 75ms forwards}.VfPpkd-ksKsZd-XxIAqe.VfPpkd-ksKsZd-mWPk3d-OWXEXe-Tv8l5d-OmS1vf::after{-webkit-animation:mdc-ripple-fg-opacity-out 150ms;animation:mdc-ripple-fg-opacity-out 150ms;-webkit-transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1));transform:translate(var(--mdc-ripple-fg-translate-end,0)) scale(var(--mdc-ripple-fg-scale,1))}.VfPpkd-ksKsZd-XxIAqe::before{background-color:#000;background-color:var(--mdc-ripple-color,#000)}.VfPpkd-ksKsZd-XxIAqe::after{background-color:#000;background-color:var(--mdc-ripple-color,#000)}.VfPpkd-ksKsZd-XxIAqe:hover::before{opacity:.04;opacity:var(--mdc-ripple-hover-opacity,0 ...
# /*# sourceURL=/_/mss/boq-dots/_/ss/k=boq-dots.DotsSplashUi.DYtAbKKZaTE.L.W.O/am=RAHfKAACAg/d=1/ed=1/ct=zgms/rs=ALs0n2N3oxHFgh4buBOeiaAOimVlGiUXgQ/m=topstories,_b,_tp */</style><script nonce="V1E+fRepipsOFwM6k5TCZA">onCssLoad();</script><style nonce="V1E+fRepipsOFwM6k5TCZA">@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}@font-face{font-family:'Material Icons Extended';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/materialiconsextended/v64/kJEjBvgX7BgnkSrUwT8UnLVc38YydejYY-oE_LvM.ttf)format('truetype');}.material-icons-extended{font-family:'Material Icons Extended';font-weight:normal;font-style:normal;font-size:24px;line-height:1;letter-spacing:normal;text-transform:none;display:inline-block;white-space:nowrap;word-wrap:normal;direction:ltr;}@font-face{font-family:'Product Sans';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/productsans/v9/pxiDypQkot1TnFhsFMOfGShVF9eL.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/googlesans/v14/4UaGrENHsxJlGDuGo1OIlL3Owps.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/googlesans/v14/4UabrENHsxJlGDuGo1OIlLU94YtzCwM.ttf)format('truetype');}@font-face{font-family:'Google Sans';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/googlesans/v14/4UabrENHsxJlGDuGo1OIlLV154tzCwM.ttf)format('truetype');}</style><script nonce="V1E+fRepipsOFwM6k5TCZA">(function(){/*
#
#  Copyright The Closure Library Authors.
#  SPDX-License-Identifier: Apache-2.0
# */
# 'use strict';var d=this||self;/*
#
#  Copyright 2011 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2013 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# var f={};function aa(a,b){if(null===b)return!1;if("contains"in a&&1==b.nodeType)return a.contains(b);if("compareDocumentPosition"in a)return a==b||!!(a.compareDocumentPosition(b)&16);for(;b&&a!=b;)b=b.parentNode;return b==a};function ba(a,b){return function(e){e||(e=window.event);return b.call(a,e)}}function u(a){a=a.target||a.srcElement;!a.getAttribute&&a.parentNode&&(a=a.parentNode);return a}var x="undefined"!=typeof navigator&&/Macintosh/.test(navigator.userAgent),ca="undefined"!=typeof navigator&&!/Opera/.test(navigator.userAgent)&&/WebKit/.test(navigator.userAgent),da={A:1,INPUT:1,TEXTAREA:1,SELECT:1,BUTTON:1};
# function ea(a){return(a=a.changedTouches&&a.changedTouches[0]||a.touches&&a.touches[0])?{clientX:a.clientX,clientY:a.clientY,screenX:a.screenX,screenY:a.screenY}:null}
# function fa(a){var b={};b.originalEventType=a.type;b.type="click";for(var e in a){var c=a[e];"type"!=e&&"srcElement"!=e&&"function"!==typeof c&&(b[e]=c)}b.timeStamp=Date.now();b.defaultPrevented=!1;b.preventDefault=ha;b._propagationStopped=!1;b.stopPropagation=ia;if(a=ea(a))b.clientX=a.clientX,b.clientY=a.clientY,b.screenX=a.screenX,b.screenY=a.screenY;return b}function la(){this._mouseEventsPrevented=!0}function ha(){this.defaultPrevented=!0}function ia(){this._propagationStopped=!0}
# var ma={A:13,BUTTON:0,CHECKBOX:32,COMBOBOX:13,FILE:0,GRIDCELL:13,LINK:13,LISTBOX:13,MENU:0,MENUBAR:0,MENUITEM:0,MENUITEMCHECKBOX:0,MENUITEMRADIO:0,OPTION:0,RADIO:32,RADIOGROUP:32,RESET:0,SUBMIT:0,SWITCH:32,TAB:0,TREE:13,TREEITEM:13},na={CHECKBOX:!0,FILE:!0,OPTION:!0,RADIO:!0},oa={COLOR:!0,DATE:!0,DATETIME:!0,"DATETIME-LOCAL":!0,EMAIL:!0,MONTH:!0,NUMBER:!0,PASSWORD:!0,RANGE:!0,SEARCH:!0,TEL:!0,TEXT:!0,TEXTAREA:!0,TIME:!0,URL:!0,WEEK:!0},pa={A:!0,AREA:!0,BUTTON:!0,DIALOG:!0,IMG:!0,INPUT:!0,LINK:!0,
# MENU:!0,OPTGROUP:!0,OPTION:!0,PROGRESS:!0,SELECT:!0,TEXTAREA:!0};/*
#
#  Copyright 2020 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# /*
#
#  Copyright 2005 Google LLC.
#  SPDX-License-Identifier: Apache-2.0
# */
# function qa(){this.s=[];this.g=[];this.l=[];this.o={};this.h=null;this.m=[]}var z,ra,sa="undefined"!=typeof navigator&&/iPhone|iPad|iPod/.test(navigator.userAgent),ta=String.prototype.trim?function(a){return a.trim()}:function(a){return a.replace(/^\s+/,"").replace(/\s+$/,"")},ua=/\s*;\s*/,A=null;
# function va(a,b){return function v(c,h){h=void 0===h?!0:h;var n=b;if("click"==n&&(x&&c.metaKey||!x&&c.ctrlKey||2==c.which||null==c.which&&4==c.button||c.shiftKey))n="clickmod";else{var l=c.which||c.keyCode;ca&&3==l&&(l=13);if(13!=l&&32!=l)l=!1;else{var g=u(c),m;(m="keydown"!=c.type||!!(!("getAttribute"in g)||(g.getAttribute("type")||g.tagName).toUpperCase()in oa||"BUTTON"==g.tagName.toUpperCase()||g.type&&"FILE"==g.type.toUpperCase()||g.isContentEditable)||c.ctrlKey||c.shiftKey||c.altKey||c.metaKey||
# (g.getAttribute("type")||g.tagName).toUpperCase()in na&&32==l)||((m=g.tagName in da)||(m=g.getAttributeNode("tabindex"),m=null!=m&&m.specified),m=!(m&&!g.disabled));if(m)l=!1;else{m=(g.getAttribute("role")||g.type||g.tagName).toUpperCase();var r=!(m in ma)&&13==l;g="INPUT"!=g.tagName.toUpperCase()||!!g.type;l=(0==ma[m]%l||r)&&g}}l&&(n="clickkey")}g=c.srcElement||c.target;l=B(n,c,g,"",null);for(m=g;m&&m!=this;m=m.__owner||m.parentNode){var k=m;b:{var q=void 0;var t=k;r=n;var ja=c;var p=t.__jsaction;
# if(!p){var y;p=null;"getAttribute"in t&&(p=t.getAttribute("jsaction"));if(y=p){p=f[y];if(!p){p={};for(var J=y.split(ua),Ea=J?J.length:0,K=0;K<Ea;K++){var C=J[K];if(C){var L=C.indexOf(":"),ka=-1!=L;p[ka?ta(C.substr(0,L)):"click"]=ka?ta(C.substr(L+1)):C}}f[y]=p}t.__jsaction=p}else p=wa,t.__jsaction=p}"maybe_click"==r&&p.click?(q=r,r="click"):"clickkey"==r?r="click":"click"!=r||p.click||(r="clickonly");y=null;if(p.click){t=xa(t,ja,p);if(!t){q={i:r,action:"",event:null,u:!0};break b}t!=ja&&(y=t,r=t.type)}q=
# {i:q?q:r,action:p[r]||"",event:y,u:!1}}if(q.u||q.action)break}q&&(l=B(q.i,q.event||c,g,q.action||"",k,l.timeStamp));l&&"touchend"==l.eventType&&(l.event._preventMouseEvents=la);if(q&&q.action){if(g="clickkey"==n)g=u(c),g=(g.type||g.tagName).toUpperCase(),(g=32==(c.which||c.keyCode)&&"CHECKBOX"!=g)||(g=u(c),m=g.tagName.toUpperCase(),q=(g.getAttribute("role")||"").toUpperCase(),g="BUTTON"===m||"BUTTON"===q?!0:!(g.tagName.toUpperCase()in pa)||"A"===m||"SELECT"===m||(g.getAttribute("type")||g.tagName).toUpperCase()in
# na||(g.getAttribute("type")||g.tagName).toUpperCase()in oa?!1:!0);g&&(c.preventDefault?c.preventDefault():c.returnValue=!1);if("mouseenter"==n||"mouseleave"==n)if(g=c.relatedTarget,!("mouseover"==c.type&&"mouseenter"==n||"mouseout"==c.type&&"mouseleave"==n)||g&&(g===k||aa(k,g)))l.action="",l.actionElement=null;else{n={};for(var w in c)"function"!==typeof c[w]&&"srcElement"!==w&&"target"!==w&&(n[w]=c[w]);n.type="mouseover"==c.type?"mouseenter":"mouseleave";n.target=n.srcElement=k;n.bubbles=!1;l.event=
# n;l.targetElement=k}}else l.action="",l.actionElement=null;k=l;a.h&&!k.event.a11ysgd&&(w=B(k.eventType,k.event,k.targetElement,k.action,k.actionElement,k.timeStamp),"clickonly"==w.eventType&&(w.eventType="click"),a.h(w,!0));if(k.actionElement){if(a.h){if(!k.actionElement||"A"!=k.actionElement.tagName||"click"!=k.eventType&&"clickmod"!=k.eventType||(c.preventDefault?c.preventDefault():c.returnValue=!1),(c=a.h(k))&&h){v.call(this,c,!1);return}}else{if((h=d.document)&&!h.createEvent&&h.createEventObject)try{var M=
# h.createEventObject(c)}catch(Ka){M=c}else M=c;k.event=M;a.m.push(k)}"touchend"==k.event.type&&k.event._mouseEventsPrevented&&(A=fa(k.event))}}}function B(a,b,e,c,h,v){return{eventType:a,event:b,targetElement:e,action:c,actionElement:h,timeStamp:v||Date.now()}}var wa={};
# function xa(a,b,e){if("click"==b.type||b.targetTouches&&1<b.targetTouches.length)return b;var c=z,h=b.target;if(h&&ya(h))return b;h=ea(b);if("touchstart"!=b.type||e.touchstart||e.touchend)if("touchend"==b.type&&c&&c.node==a)if(b.defaultPrevented||h&&4<Math.abs(h.clientX-c.x)+Math.abs(h.clientY-c.y))z=null;else{A=a=fa(b);b.stopPropagation();b.preventDefault();document.createEvent?(b=document.createEvent("MouseEvent"),b.initMouseEvent(a.type,!0,!0,window,a.detail||1,a.screenX||0,a.screenY||0,a.clientX||
# 0,a.clientY||0,a.ctrlKey||!1,a.altKey||!1,a.shiftKey||!1,a.metaKey||!1,a.button||0,a.relatedTarget||null)):(b=document.createEventObject(),b.type=a.type,b.clientX=a.clientX,b.clientY=a.clientY,b.button=a.button,b.detail=a.detail,b.ctrlKey=a.ctrlKey,b.altKey=a.altKey,b.shiftKey=a.shiftKey,b.metaKey=a.metaKey);b.v=a.timeStamp;b._fastclick=!0;a:{for(e=a.target;e&&e.getAttribute;){c=e.tagName||"";if("A"==c||"INPUT"==c||"TEXTAREA"==c||"SELECT"==c||"BUTTON"==c||e.getAttribute("tabIndex"))break a;e=e.parentNode}e=
# null}e?e.focus():document.activeElement&&document.activeElement.blur();a.target.dispatchEvent(b);if(!b.defaultPrevented){if(document.activeElement&&document.activeElement!=b.target&&document.activeElement!=e&&ya(document.activeElement))try{document.activeElement.blur()}catch(v){}try{window.getSelection().removeAllRanges()}catch(v){}}return null}else"touchmove"==b.type&&c&&h&&4<Math.abs(h.clientX-c.x)+Math.abs(h.clientY-c.y)&&(z=null);else return z={node:a,x:h?h.clientX:0,y:h?h.clientY:0},A=null,clearTimeout(ra),
# ra=setTimeout(za,400),null;return b}function ya(a){var b=a.tagName||"";return"TEXTAREA"==b||"INPUT"==b||"SELECT"==b||"OPTION"==b||a.isContentEditable}function za(){z=null}function D(a){if(!a._fastclick){var b=A;if(b)if(800<Date.now()-b.timeStamp)A=null;else{var e=4>=Math.abs(a.clientX-b.clientX)+Math.abs(a.clientY-b.clientY);b.target==a.target||e?(a.stopPropagation(),a.preventDefault(),"click"==a.type&&(A=null)):A=null}}}
# function Aa(a,b){return function(e){var c=a,h=b,v=!1;"mouseenter"==c?c="mouseover":"mouseleave"==c&&(c="mouseout");if(e.addEventListener){if("focus"==c||"blur"==c||"error"==c||"load"==c)v=!0;e.addEventListener(c,h,v)}else e.attachEvent&&("focus"==c?c="focusin":"blur"==c&&(c="focusout"),h=ba(e,h),e.attachEvent("on"+c,h));return{i:c,j:h,capture:v}}}
# function E(a,b,e){if(!a.o.hasOwnProperty(b)){var c=va(a,b);e=Aa(e||b,c);a.o[b]=c;a.s.push(e);for(c=0;c<a.g.length;++c){var h=a.g[c];h.h.push(e.call(null,h.g))}"click"==b&&E(a,"keydown");"click"==b&&(E(a,"touchstart"),E(a,"touchend"),E(a,"touchmove"),document.addEventListener&&(document.addEventListener("click",D,!0),document.addEventListener("mouseup",D,!0),document.addEventListener("mousedown",D,!0)))}}qa.prototype.j=function(a){return this.o[a]};
# function Ba(a){var b=F,e=a.g;sa&&(e.style.cursor="pointer");for(e=0;e<b.s.length;++e)a.h.push(b.s[e].call(null,a.g))}function Ca(a){for(var b=Da,e=0;e<b.length;++e)if(b[e].g!=a.g&&Fa(b[e].g,a.g))return!0;return!1}function Fa(a,b){for(;a!=b&&b.parentNode;)b=b.parentNode;return a==b};var G=window,F=new qa;var Ga=G.document.documentElement,H=new function(a){this.g=a;this.h=[]}(Ga),I;b:{for(var N=0;N<F.g.length;N++)if(Fa(F.g[N].g,Ga)){I=!0;break b}I=!1}
# if(I)F.l.push(H);else{Ba(H);F.g.push(H);for(var Da=F.l.concat(F.g),O=[],P=[],Q=0;Q<F.g.length;++Q){var R=F.g[Q];if(Ca(R)){O.push(R);for(var S=0;S<R.h.length;++S){var T=R.g,U=R.h[S];T.removeEventListener?T.removeEventListener(U.i,U.j,U.capture):T.detachEvent&&T.detachEvent("on"+U.i,U.j)}R.h=[]}else P.push(R)}for(var V=0;V<F.l.length;++V){var W=F.l[V];Ca(W)?O.push(W):(P.push(W),Ba(W))}F.g=P;F.l=O}E(F,"click");E(F,"dblclick");E(F,"focus");E(F,"focusin");E(F,"blur");E(F,"error");E(F,"focusout");E(F,"keydown");
# E(F,"keyup");E(F,"keypress");E(F,"load");E(F,"mouseover");E(F,"mouseout");E(F,"mouseenter");E(F,"mouseleave");E(F,"submit");E(F,"touchstart");E(F,"touchend");E(F,"touchmove");E(F,"auxclick");E(F,"change");E(F,"compositionstart");E(F,"compositionupdate");E(F,"compositionend");E(F,"input");E(F,"textinput");E(F,"copy");E(F,"cut");E(F,"paste");E(F,"mousedown");E(F,"mouseup");E(F,"wheel");E(F,"contextmenu");E(F,"dragover");E(F,"dragenter");E(F,"dragleave");E(F,"drop");E(F,"dragstart");E(F,"dragend");
# E(F,"pointerdown");E(F,"pointerup");E(F,"ended");E(F,"loadedmetadata");var Ha,Ia;"onwebkitanimationend"in G&&(Ha="webkitAnimationEnd");E(F,"animationend",Ha);"onwebkittransitionend"in G&&(Ia="webkitTransitionEnd");E(F,"transitionend",Ia);
# var Ja=function(a){return{trigger:function(b){var e=a.j(b.type);e||(E(a,b.type),e=a.j(b.type));var c=b.target||b.srcElement;e&&e.call(c.ownerDocument.documentElement,b)},bind:function(b){a.h=b;a.m&&(0<a.m.length&&b(a.m),a.m=null)}}}(F),X=["BOQ_wizbind"],Y=window||d;X[0]in Y||"undefined"==typeof Y.execScript||Y.execScript("var "+X[0]);for(var Z;X.length&&(Z=X.shift());)X.length||void 0===Ja?Y[Z]&&Y[Z]!==Object.prototype[Z]?Y=Y[Z]:Y=Y[Z]={}:Y[Z]=Ja;}).call(this);
# </script><script href="https://www.gstatic.com/_/mss/boq-dots/_/js/k=boq-dots.DotsSplashUi.en_IN.1xdCVizdApQ.es5.O/am=RAHfKAACAg/d=1/excm=_b,_tp,topstories/ed=1/dg=0/wt=2/ct=zgms/rs=ALs0n2ON9vRn-uQKBE0JnfmtSo1ig3i0Kg/m=_b,_tp" id="base-js" nocollect="" nonce="V1E+fRepipsOFwM6k5TCZA">"use strict";this.default_DotsSplashUi=this.default_DotsSplashUi||{};(function(_){var window=this;
# try{
# var baa,caa,gaa,haa,iaa,jaa,kaa,maa,naa,oaa,qaa,raa,taa,Hc,waa,Eaa,Aaa,Gaa,Haa,Kaa,Laa,Oaa,Fd,Id,Jd,Qaa,Raa,aaa,Saa,Td,Taa,Vd,Uaa,Vaa,Yd,$d,ae,be,Zaa,fe,ge;_.aa=function(a){return function(){return aaa[a].apply(this,arguments)}};_.ba=function(a,b){return aaa[a]=b};_.fa=function(a){_.da.setTimeout(function(){throw a;},0)};_.ha=function(a){a&&"function"==typeof a.Be&&a.Be()};baa=function(a){for(var b=0,c=arguments.length;b<c;++b){var d=arguments[b];_.ia(d)?baa.apply(null,d):_.ha(d)}};
# _.ja=function(a){if(Error.captureStackTrace)Error.captureStackTrace(this,_.ja);else{var b=Error().stack;b&&(this.stack=b)}a&&(this.message=String(a));this.j=!0};_.ka=function(a){return a[a.length-1]};_.oa=function(a,b,c){for(var d="string"===typeof a?a.split(""):a,e=a.length-1;0<=e;--e)e in d&&b.call(c,d[e],e,a)};_.qa=function(a,b,c){b=_.pa(a,b,c);return 0>b?null:"string"===typeof a?a.charAt(b):a[b]};
# _.pa=function(a,b,c){for(var d=a.length,e="string"===typeof a?a.split(""):a,f=0;f<d;f++)if(f in e&&b.call(c,e[f],f,a))return f;return-1};_.sa=function(a,b){return 0<=(0,_.ra)(a,b)};_.ta=function(a){if(!Array.isArray(a))for(var b=a.length-1;0<=b;b--)delete a[b];a.length=0};_.ua=function(a,b){_.sa(a,b)||a.push(b)};_.wa=function(a,b){b=(0,_.ra)(a,b);var c;(c=0<=b)&&_.va(a,b);return c};_.va=function(a,b){return 1==Array.prototype.splice.call(a,b,1).length};
# _.Aa=function(a,b,c){var d=0;_.oa(a,function(e,f){b.call(c,e,f,a)&&_.va(a,f)&&d++});return d};_.Ba=function(a){return Array.prototype.concat.apply([],arguments)};_.Ca=function(a){var b=a.length;if(0<b){for(var c=Array(b),d=0;d<b;d++)c[d]=a[d];return c}return[]};_.Fa=function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(_.ia(d)){var e=a.length||0,f=d.length||0;a.length=e+f;for(var g=0;g<f;g++)a[e+g]=d[g]}else a.push(d)}};
# _.Ha=function(a,b,c,d){Array.prototype.splice.apply(a,_.Ga(arguments,1))};_.Ga=function(a,b,c){return 2>=arguments.length?Array.prototype.slice.call(a,b):Array.prototype.slice.call(a,b,c)};_.La=function(a,b){b=b||a;for(var c={},d=0,e=0;e<a.length;){var f=a[e++];var g=f;g=_.Ia(g)?"o"+_.Ja(g):(typeof g).charAt(0)+g;Object.prototype.hasOwnProperty.call(c,g)||(c[g]=!0,b[d++]=f)}b.length=d};_.Na=function(a,b){a.sort(b||_.Ma)};
# _.Oa=function(a,b,c){if(!_.ia(a)||!_.ia(b)||a.length!=b.length)return!1;var d=a.length;c=c||caa;for(var e=0;e<d;e++)if(!c(a[e],b[e]))return!1;return!0};_.Ma=function(a,b){return a>b?1:a<b?-1:0};caa=function(a,b){return a===b};_.daa=function(a,b){var c={};(0,_.Qa)(a,function(d,e){c[b.call(void 0,d,e,a)]=d});return c};_.Ra=function(a,b){var c=[],d=0,e=a;void 0!==b&&(d=a,e=b);if(0>e-d)return[];for(a=d;a<e;a+=1)c.push(a);return c};
# _.Ua=function(a){for(var b=[],c=0;c<arguments.length;c++){var d=arguments[c];if(Array.isArray(d))for(var e=0;e<d.length;e+=8192)for(var f=_.Ua.apply(null,_.Ga(d,e,e+8192)),g=0;g<f.length;g++)b.push(f[g]);else b.push(d)}return b};_.ab=function(){!_.Va&&_.$a&&(_.Va=(0,_.$a)());return _.Va};_.m=function(a){if(_.Va){var b=_.Va;b.ha=b.Bq(a)}};_.u=function(){_.Va&&_.Va.Wb()};_.eaa=function(a,b){return(b=b.WIZ_global_data)&&a in b?b[a]:null};_.pb=function(a){"__jsaction"in a&&delete a.__jsaction};
# _.wb=function(a,b){b.displayName=a;b[faa]=a};gaa=function(a){a=a[faa];return a instanceof _.xb?a:null};_.yb=function(a,b){this.ha=a;this.j=b;this.constructor.M3||(this.constructor.M3={});this.constructor.M3[this.toString()]=this};haa=function(a){_.Lb(null,a)};iaa=function(){};jaa=function(a){var b=this.getAttribute(a);Element.prototype.setAttribute.apply(this,arguments);var c=this.getAttribute(a);_.Mb(this,Zb,{name:a,KB:c,kva:b},!1,void 0)};
# kaa=function(a){var b=this.getAttribute(a);Element.prototype.removeAttribute.apply(this,arguments);_.Mb(this,Zb,{name:a,KB:null,kva:b},!1,void 0)};maa=function(a){this.Ca={};this.j=[];var b=laa;this.ka=function(c){if(c=b(c))c.Za=!0;return c};this.ha=a;this.ta={};this.o=null};_.ic=function(a){return _.Ia(a)&&void 0!==a.Wc&&a.Wc instanceof _.hc&&void 0!==a.uc&&(void 0===a.Qd||a.Qd instanceof _.w)?!0:!1};naa=function(a){var b=a.qfb;_.ic(a)&&(b=a.metadata?!a.metadata.fatal:void 0);return b};
# oaa=function(a){var b=a.tu;_.ic(a)&&(b=a.metadata?a.metadata.tu:void 0);return b};qaa=function(a,b){var c=oaa(a);if(null==c||0>c)return b;var d=!1;b.then(function(){d=!0},function(){});c=_.jc(c,_.kc(null));a.metadata&&(a.metadata.f8=!1);c.then(function(){a.metadata&&(a.metadata.f8=!d)});return _.paa([b,c])};raa=function(a,b){return naa(a)?_.rc(b,function(){return _.kc(null)}):b};
# taa=function(a,b){return _.ic(a)&&a.metadata&&a.metadata.iwa?b.then(function(c){if(!c&&a.metadata&&a.metadata.f8){c=new saa;var d=new _.tc,e;e||(e="type.googleapis.com/");"/"!=e.substr(-1)?_.uc(d,1,e+"/wiz.data.clients.WizDataTimeoutError"):_.uc(d,1,e+"wiz.data.clients.WizDataTimeoutError");_.x(d,2,c.Rd());e=[d];c=new _.vc;c=_.wc(c,1,2,0);return _.yc(c,3,e)}return null},function(c){return"undefined"!=typeof _.zc&&c instanceof _.zc?c.status:null}):b};
# Hc=function(a){if(!_.Ac.has("startup"))throw Error("la`startup");_.uaa.has("startup")?a.apply():_.Dc.startup.push(a)};waa=function(){var a={};a.location=document.location.toString();if(vaa())try{a["top.location"]=top.location.toString()}catch(c){a["top.location"]="[external]"}else a["top.location"]="[external]";for(var b in Mc)try{a[b]=Mc[b].call()}catch(c){a[b]="[error] "+c.message}return a};
# Eaa=function(a){Nc.init();a&&(a=new Qc(a,void 0,!0),a=new xaa(a),_.Tc.j=a,yaa(a));var b=null;a=function(c){_.da.$googDebugFname&&c&&c.message&&!c.fileName&&(c.message+=" in "+_.da.$googDebugFname);b?c&&c.message&&(c.message+=" [Possibly caused by: "+b+"]"):b=String(c);_.Lb(null,c)};_.Uc("_DumpException",a,void 0);_.Uc("_B_err",a,void 0);_.Qa([_.da].concat([]),_.Vc(zaa,_.Vc(Aaa,!0),!0));_.Wc()&&Zc(28)||_.bd()&&Zc(14)||_.cd()&&Zc(11)||_.dd()&&Zc(10);if(!_.ed||_.fd(10))a=new gd(haa),a.o=!0,a.j=!0,Baa(a),
# hd(a,"setTimeout"),hd(a,"setInterval"),Caa(a),Daa(a),_.Tc.o=a};Aaa=function(a,b){-1==b.message.indexOf("Error in protected function: ")&&(b.error&&b.error.stack?_.Lb(null,b.error):a||_.Lb(null,b))};
# Gaa=function(a){var b=!0;b=void 0===b?!1:b;a=void 0===a?!1:a;var c=void 0===c?{}:c;var d="",e="";window&&window._F_cssRowKey&&(d=window._F_cssRowKey,window._F_combinedSignature&&(e=window._F_combinedSignature));if(d&&"function"!==typeof window._F_installCss)throw Error("qa");var f="";var g=_.da._F_jsUrl,h=document.getElementById("base-js");if(h){var l=h.tagName.toUpperCase();if("SCRIPT"==l||"LINK"==l)f=h.src?h.src:h.getAttribute("href")}if(g&&f){if(g!=f)throw Error("oa`"+g+"`"+f);f=g}else f=g||f;
# if(!Faa(f))throw Error("pa");a=new _.id(_.jd(f),d,e,b,a);c.eJ&&(a.eJ=c.eJ);c=_.ab();c.Za=a;c.hba(!0);return a};_.ld=function(a,b){var c=_.kd[a];c||(c=_.kd[a]=[]);c.push(b)};Haa=function(){var a=void 0,b,c;void 0===a&&(a={});return{a5:null!==(b=a.a5)&&void 0!==b?b:null,ica:null!==(c=a.ica)&&void 0!==c?c:!1}};
# Kaa=function(){var a,b=Haa(),c=_.md(_.nd("GASP4"),Iaa,-1);Jaa(c,new _.od(!1,!0),b.ica?void 0:140,{MI:_.pd.Fb(),Kr:null!==(a=b.a5)&&void 0!==a?a:void 0});_.ld(_.qd,function(d){var e,f,g,h=_.nd("hbSvMb"),l=[];h&&h.Mc()&&(l=h.ha().map(function(p){return p.number()}));h=_.nd("Ze7Mzd");var n=[];h&&h.Mc()&&(h=_.rd(h,_.sd),n=null!==(g=null===(f=null===(e=null===h||void 0===h?void 0:h.getItem())||void 0===e?void 0:e.wL())||void 0===f?void 0:_.td(f,1))&&void 0!==g?g:[]);l=Array.from(new Set(l.concat(n)));
# d.Wb(_.ud(l))})};
# Laa=function(a,b,c,d){if(a=a.j&&a.j[c])if(a instanceof _.vd){d=new _.vd([],a.ha);d.j=!1;for(var e in a.map){var f=a.map[e].key,g=a.map[e].value,h=a.map[e].j;h?d.set(f,_.wd(h)):(h=d,g=Array.isArray(g)?xd(g):g,h.map[f.toString()]=new yd(f,g),h.j=!1)}d.ka=_.zd;_.Ad(b,c,d)}else Array.isArray(a)?(Object.isFrozen(a)?e=a:(e=_.Bd(a,_.wd),_.zd(e)),_.yc(b,c,e)):_.Ad(b,c,_.wd(a));else Array.isArray(d)?_.x(b,c,Object.isFrozen(d)?d:xd(d)):Cd&&d instanceof Uint8Array?_.x(b,c,null==d||"string"===typeof d?d:Cd&&
# d instanceof Uint8Array?_.Dd(d):null):_.x(b,c,d)};_.wd=function(a){if(_.Ed(a))return a;for(var b=new a.constructor,c=0;c<a.ha.length;c++){var d=a.ha[c];if(Maa(d))for(var e in d)Laa(a,b,_.Naa(e),d[e]);else Laa(a,b,c-a.Ca,d)}_.zd(b);return b};Oaa=function(a,b){var c=[];(a=a.getContent())&&(c=Fd(a,b));return c};Fd=function(a,b){return(a&&a.Qa()||[]).reduce(function(c,d){var e=b(d);e?c=c.concat(e instanceof Array?e:[e]):_.Gd(d,3)&&(d=d.Ra())&&(d=Fd(d,b),d.length&&(c=c.concat(d)));return c},[])};
# _.Hd=function(){};Id=function(){};Jd=function(a){a=a.__soy;a.Dxa();return a};Qaa=function(a){for(;a&&!a.r3&&!Paa(a);)a=a.parentElement;return{element:a,p8:a.r3}};
# Raa=function(){_.Kd({Xa:function(a){var b=a.Aa?a.Aa().el():a.Cq();var c=b.__soy?Jd(b):null;if(c)return _.kc(c);var d=Qaa(b),e=d.element;e.qR||(e.qR=new Set);var f=e.qR;c=new Set;for(var g=_.Ld(f),h=g.next();!h.done;h=g.next())h=h.value,_.Md(b,h)&&c.add(h);c.size||(f.add(b),b.__soy_tagged_for_skip=!0);a=d.p8?d.p8.then(function(){f.clear();var l=b.__soy?Jd(b):null;if(l)return l;e.__soy.render();return Jd(b)}):_.Nd([a.Yj(_.Od,d.element),_.Qd(a,{Ia:{eO:_.Rd}})]).then(function(l){var n=l[1].Ia.eO;return l[0].ima().then(function(p){f.clear();
# e.__incrementalDOMData||(_.Sd(e),n.Doa(e,p.template,p.args));if((!b.__soy||!Jd(b))&&e.__incrementalDOMData){p="Hydration source "+(document.body.contains(e)?"in dom":"not in dom")+";";var q="El source "+(document.body.contains(b)?"in dom":"not in dom");_.fa(Error("za`"+p+"`"+q+"`"+(b.getAttribute("jscontroller")||b.getAttribute("jsmodel"))));return null}return Jd(b)})});b.qR=c;b.r3=a;return a.then(function(l){return l})}})};aaa=[];
# Saa=function(a){var b=0;return function(){return b<a.length?{done:!1,value:a[b++]}:{done:!0}}};Td="function"==typeof Object.defineProperties?Object.defineProperty:function(a,b,c){if(a==Array.prototype||a==Object.prototype)return a;a[b]=c.value;return a};Taa=function(a){a=["object"==typeof globalThis&&globalThis,a,"object"==typeof window&&window,"object"==typeof self&&self,"object"==typeof global&&global];for(var b=0;b<a.length;++b){var c=a[b];if(c&&c.Math==Math)return c}throw Error("a");};_.Ud=Taa(this);
# Vd=function(a,b){if(b)a:{var c=_.Ud;a=a.split(".");for(var d=0;d<a.length-1;d++){var e=a[d];if(!(e in c))break a;c=c[e]}a=a[a.length-1];d=c[a];b=b(d);b!=d&&null!=b&&Td(c,a,{configurable:!0,writable:!0,value:b})}};
# Vd("Symbol",function(a){if(a)return a;var b=function(e,f){this.j=e;Td(this,"description",{configurable:!0,writable:!0,value:f})};b.prototype.toString=function(){return this.j};var c=0,d=function(e){if(this instanceof d)throw new TypeError("b");return new b("jscomp_symbol_"+(e||"")+"_"+c++,e)};return d});
# Vd("Symbol.iterator",function(a){if(a)return a;a=Symbol("c");for(var b="Array Int8Array Uint8Array Uint8ClampedArray Int16Array Uint16Array Int32Array Uint32Array Float32Array Float64Array".split(" "),c=0;c<b.length;c++){var d=_.Ud[b[c]];"function"===typeof d&&"function"!=typeof d.prototype[a]&&Td(d.prototype,a,{configurable:!0,writable:!0,value:function(){return Uaa(Saa(this))}})}return a});Uaa=function(a){a={next:a};a[Symbol.iterator]=function(){return this};return a};
# _.Ld=function(a){var b="undefined"!=typeof Symbol&&Symbol.iterator&&a[Symbol.iterator];return b?b.call(a):{next:Saa(a)}};_.Wd=function(a){for(var b,c=[];!(b=a.next()).done;)c.push(b.value);return c};_.Xd=function(a){return a instanceof Array?a:_.Wd(_.Ld(a))};Vaa="function"==typeof Object.create?Object.create:function(a){var b=function(){};b.prototype=a;return new b};
# if("function"==typeof Object.setPrototypeOf)Yd=Object.setPrototypeOf;else{var Zd;a:{var Waa={a:!0},Xaa={};try{Xaa.__proto__=Waa;Zd=Xaa.a;break a}catch(a){}Zd=!1}Yd=Zd?function(a,b){a.__proto__=b;if(a.__proto__!==b)throw new TypeError("d`"+a);return a}:null}$d=Yd;
# _.y=function(a,b){a.prototype=Vaa(b.prototype);a.prototype.constructor=a;if($d)$d(a,b);else for(var c in b)if("prototype"!=c)if(Object.defineProperties){var d=Object.getOwnPropertyDescriptor(b,c);d&&Object.defineProperty(a,c,d)}else a[c]=b[c];a.Jd=b.prototype};ae=function(){this.Ca=!1;this.ka=null;this.o=void 0;this.j=1;this.Ja=this.ha=0;this.ta=null};be=function(a){if(a.Ca)throw new TypeError("f");a.Ca=!0};ae.prototype.Fa=function(a){this.o=a};var ce=function(a,b){a.ta={E5:b,cpa:!0};a.j=a.ha||a.Ja};
# ae.prototype.return=function(a){this.ta={return:a};this.j=this.Ja};_.de=function(a,b,c){a.j=c;return{value:b}};_.ee=function(a){a.j=0};_.Yaa=function(a){this.j=new ae;this.o=a};Zaa=function(a,b){be(a.j);var c=a.j.ka;if(c)return fe(a,"return"in c?c["return"]:function(d){return{value:d,done:!0}},b,a.j.return);a.j.return(b);return ge(a)};
# fe=function(a,b,c,d){try{var e=b.call(a.j.ka,c);if(!(e instanceof Object))throw new TypeError("e`"+e);if(!e.done)return a.j.Ca=!1,e;var f=e.value}catch(g){return a.j.ka=null,ce(a.j,g),ge(a)}a.j.ka=null;d.call(a.j,f);return ge(a)};ge=function(a){for(;a.j.j;)try{var b=a.o(a.j);if(b)return a.j.Ca=!1,{value:b.value,done:!1}}catch(c){a.j.o=void 0,ce(a.j,c)}a.j.Ca=!1;if(a.j.ta){b=a.j.ta;a.j.ta=null;if(b.cpa)throw b.E5;return{value:b.return,done:!0}}return{value:void 0,done:!0}};
# _.$aa=function(a){this.next=function(b){be(a.j);a.j.ka?b=fe(a,a.j.ka.next,b,a.j.Fa):(a.j.Fa(b),b=ge(a));return b};this.throw=function(b){be(a.j);a.j.ka?b=fe(a,a.j.ka["throw"],b,a.j.Fa):(ce(a.j,b),b=ge(a));return b};this.return=function(b){return Zaa(a,b)};this[Symbol.iterator]=function(){return this}};_.he=function(a,b){b=new _.$aa(new _.Yaa(b));$d&&a.prototype&&$d(b,a.prototype);return b};
# Vd("Promise",function(a){function b(){this.j=null}function c(g){return g instanceof e?g:new e(function(h){h(g)})}if(a)return a;b.prototype.o=function(g){if(null==this.j){this.j=[];var h=this;this.ha(function(){h.ta()})}this.j.push(g)};var d=_.Ud.setTimeout;b.prototype.ha=function(g){d(g,0)};b.prototype.ta=function(){for(;this.j&&this.j.length;){var g=this.j;this.j=[];for(var h=0;h<g.length;++h){var l=g[h];g[h]=null;try{l()}catch(n){this.ka(n)}}}this.j=null};b.prototype.ka=function(g){this.ha(function(){throw g;
# })};var e=function(g){this.Db=0;this.jh=void 0;this.j=[];this.ta=!1;var h=this.ha();try{g(h.resolve,h.reject)}catch(l){h.reject(l)}};e.prototype.ha=function(){function g(n){return function(p){l||(l=!0,n.call(h,p))}}var h=this,l=!1;return{resolve:g(this.Ma),reject:g(this.o)}};e.prototype.Ma=function(g){if(g===this)this.o(new TypeError("g"));else if(g instanceof e)this.$a(g);else{a:switch(typeof g){case "object":var h=null!=g;break a;case "function":h=!0;break a;default:h=!1}h?this.Ka(g):this.ka(g)}};
# e.prototype.Ka=function(g){var h=void 0;try{h=g.then}catch(l){this.o(l);return}"function"==typeof h?this.Za(h,g):this.ka(g)};e.prototype.o=function(g){this.Ca(2,g)};e.prototype.ka=function(g){this.Ca(1,g)};e.prototype.Ca=function(g,h){if(0!=this.Db)throw Error("h`"+g+"`"+h+"`"+this.Db);this.Db=g;this.jh=h;2===this.Db&&this.Wa();this.Fa()};e.prototype.Wa=function(){var g=this;d(function(){if(g.Ja()){var h=_.Ud.console;"undefined"!==typeof h&&h.error(g.jh)}},1)};e.prototype.Ja=function(){if(this.ta)return!1;
# var g=_.Ud.CustomEvent,h=_.Ud.Event,l=_.Ud.dispatchEvent;if("undefined"===typeof l)return!0;"function"===typeof g?g=new g("unhandledrejection",{cancelable:!0}):"function"===typeof h?g=new h("unhandledrejection",{cancelable:!0}):(g=_.Ud.document.createEvent("CustomEvent"),g.initCustomEvent("unhandledrejection",!1,!0,g));g.promise=this;g.reason=this.jh;return l(g)};e.prototype.Fa=function(){if(null!=this.j){for(var g=0;g<this.j.length;++g)f.o(this.j[g]);this.j=null}};var f=new b;e.prototype.$a=function(g){var h=
# this.ha();g.pK(h.resolve,h.reject)};e.prototype.Za=function(g,h){var l=this.ha();try{g.call(h,l.resolve,l.reject)}catch(n){l.reject(n)}};e.prototype.then=function(g,h){function l(r,t){return"function"==typeof r?function(v){try{n(r(v))}catch(z){p(z)}}:t}var n,p,q=new e(function(r,t){n=r;p=t});this.pK(l(g,n),l(h,p));return q};e.prototype.catch=function(g){return this.then(void 0,g)};e.prototype.pK=function(g,h){function l(){switch(n.Db){case 1:g(n.jh);break;case 2:h(n.jh);break;default:throw Error("i`"+
# n.Db);}}var n=this;null==this.j?f.o(l):this.j.push(l);this.ta=!0};e.resolve=c;e.reject=function(g){return new e(function(h,l){l(g)})};e.race=function(g){return new e(function(h,l){for(var n=_.Ld(g),p=n.next();!p.done;p=n.next())c(p.value).pK(h,l)})};e.all=function(g){var h=_.Ld(g),l=h.next();return l.done?c([]):new e(function(n,p){function q(v){return function(z){r[v]=z;t--;0==t&&n(r)}}var r=[],t=0;do r.push(void 0),t++,c(l.value).pK(q(r.length-1),p),l=h.next();while(!l.done)})};return e});
# var aba=function(a,b,c){a instanceof String&&(a=String(a));for(var d=a.length,e=0;e<d;e++){var f=a[e];if(b.call(c,f,e,a))return{q8:e,Vca:f}}return{q8:-1,Vca:void 0}};Vd("Array.prototype.find",function(a){return a?a:function(b,c){return aba(this,b,c).Vca}});var ie=function(a,b,c){if(null==a)throw new TypeError("j`"+c);if(b instanceof RegExp)throw new TypeError("k`"+c);return a+""};
# Vd("String.prototype.endsWith",function(a){return a?a:function(b,c){var d=ie(this,b,"endsWith");void 0===c&&(c=d.length);c=Math.max(0,Math.min(c|0,d.length));for(var e=b.length;0<e&&0<c;)if(d[--c]!=b[--e])return!1;return 0>=e}});Vd("String.prototype.startsWith",function(a){return a?a:function(b,c){var d=ie(this,b,"startsWith"),e=d.length,f=b.length;c=Math.max(0,Math.min(c|0,d.length));for(var g=0;g<f&&c<e;)if(d[c++]!=b[g++])return!1;return g>=f}});
# Vd("String.prototype.repeat",function(a){return a?a:function(b){var c=ie(this,null,"repeat");if(0>b||1342177279<b)throw new RangeError("l");b|=0;for(var d="";b;)if(b&1&&(d+=c),b>>>=1)c+=c;return d}});var je=function(a,b){a instanceof String&&(a+="");var c=0,d=!1,e={next:function(){if(!d&&c<a.length){var f=c++;return{value:b(f,a[f]),done:!1}}d=!0;return{done:!0,value:void 0}}};e[Symbol.iterator]=function(){return e};return e};
# Vd("Array.prototype.entries",function(a){return a?a:function(){return je(this,function(b,c){return[b,c]})}});Vd("Array.prototype.keys",function(a){return a?a:function(){return je(this,function(b){return b})}});var ke=function(a,b){return Object.prototype.hasOwnProperty.call(a,b)};
# Vd("WeakMap",function(a){function b(){}function c(l){var n=typeof l;return"object"===n&&null!==l||"function"===n}function d(l){if(!ke(l,f)){var n=new b;Td(l,f,{value:n})}}function e(l){var n=Object[l];n&&(Object[l]=function(p){if(p instanceof b)return p;Object.isExtensible(p)&&d(p);return n(p)})}if(function(){if(!a||!Object.seal)return!1;try{var l=Object.seal({}),n=Object.seal({}),p=new a([[l,2],[n,3]]);if(2!=p.get(l)||3!=p.get(n))return!1;p.delete(l);p.set(n,4);return!p.has(l)&&4==p.get(n)}catch(q){return!1}}())return a;
# var f="$jscomp_hidden_"+Math.random();e("freeze");e("preventExtensions");e("seal");var g=0,h=function(l){this.j=(g+=Math.random()+1).toString();if(l){l=_.Ld(l);for(var n;!(n=l.next()).done;)n=n.value,this.set(n[0],n[1])}};h.prototype.set=function(l,n){if(!c(l))throw Error("m");d(l);if(!ke(l,f))throw Error("n`"+l);l[f][this.j]=n;return this};h.prototype.get=function(l){return c(l)&&ke(l,f)?l[f][this.j]:void 0};h.prototype.has=function(l){return c(l)&&ke(l,f)&&ke(l[f],this.j)};h.prototype.delete=function(l){return c(l)&&
# ke(l,f)&&ke(l[f],this.j)?delete l[f][this.j]:!1};return h});Vd("Object.is",function(a){return a?a:function(b,c){return b===c?0!==b||1/b===1/c:b!==b&&c!==c}});Vd("Array.prototype.includes",function(a){return a?a:function(b,c){var d=this;d instanceof String&&(d=String(d));var e=d.length;c=c||0;for(0>c&&(c=Math.max(c+e,0));c<e;c++){var f=d[c];if(f===b||Object.is(f,b))return!0}return!1}});
# Vd("String.prototype.includes",function(a){return a?a:function(b,c){return-1!==ie(this,b,"includes").indexOf(b,c||0)}});Vd("Object.values",function(a){return a?a:function(b){var c=[],d;for(d in b)ke(b,d)&&c.push(b[d]);return c}});
# Vd("Map",function(a){if(function(){if(!a||"function"!=typeof a||!a.prototype.entries||"function"!=typeof Object.seal)return!1;try{var h=Object.seal({x:4}),l=new a(_.Ld([[h,"s"]]));if("s"!=l.get(h)||1!=l.size||l.get({x:4})||l.set({x:4},"t")!=l||2!=l.size)return!1;var n=l.entries(),p=n.next();if(p.done||p.value[0]!=h||"s"!=p.value[1])return!1;p=n.next();return p.done||4!=p.value[0].x||"t"!=p.value[1]||!n.next().done?!1:!0}catch(q){return!1}}())return a;var b=new WeakMap,c=function(h){this.o={};this.j=
# f();this.size=0;if(h){h=_.Ld(h);for(var l;!(l=h.next()).done;)l=l.value,this.set(l[0],l[1])}};c.prototype.set=function(h,l){h=0===h?0:h;var n=d(this,h);n.list||(n.list=this.o[n.id]=[]);n.Wi?n.Wi.value=l:(n.Wi={next:this.j,Fp:this.j.Fp,head:this.j,key:h,value:l},n.list.push(n.Wi),this.j.Fp.next=n.Wi,this.j.Fp=n.Wi,this.size++);return this};c.prototype.delete=function(h){h=d(this,h);return h.Wi&&h.list?(h.list.splice(h.index,1),h.list.length||delete this.o[h.id],h.Wi.Fp.next=h.Wi.next,h.Wi.next.Fp=
# h.Wi.Fp,h.Wi.head=null,this.size--,!0):!1};c.prototype.clear=function(){this.o={};this.j=this.j.Fp=f();this.size=0};c.prototype.has=function(h){return!!d(this,h).Wi};c.prototype.get=function(h){return(h=d(this,h).Wi)&&h.value};c.prototype.entries=function(){return e(this,function(h){return[h.key,h.value]})};c.prototype.keys=function(){return e(this,function(h){return h.key})};c.prototype.values=function(){return e(this,function(h){return h.value})};c.prototype.forEach=function(h,l){for(var n=this.entries(),
# p;!(p=n.next()).done;)p=p.value,h.call(l,p[1],p[0],this)};c.prototype[Symbol.iterator]=c.prototype.entries;var d=function(h,l){var n=l&&typeof l;"object"==n||"function"==n?b.has(l)?n=b.get(l):(n=""+ ++g,b.set(l,n)):n="p_"+l;var p=h.o[n];if(p&&ke(h.o,n))for(h=0;h<p.length;h++){var q=p[h];if(l!==l&&q.key!==q.key||l===q.key)return{id:n,list:p,index:h,Wi:q}}return{id:n,list:p,index:-1,Wi:void 0}},e=function(h,l){var n=h.j;return Uaa(function(){if(n){for(;n.head!=h.j;)n=n.Fp;for(;n.next!=n.head;)return n=
# n.next,{done:!1,value:l(n)};n=null}return{done:!0,value:void 0}})},f=function(){var h={};return h.Fp=h.next=h.head=h},g=0;return c});
# Vd("Set",function(a){if(function(){if(!a||"function"!=typeof a||!a.prototype.entries||"function"!=typeof Object.seal)return!1;try{var c=Object.seal({x:4}),d=new a(_.Ld([c]));if(!d.has(c)||1!=d.size||d.add(c)!=d||1!=d.size||d.add({x:4})!=d||2!=d.size)return!1;var e=d.entries(),f=e.next();if(f.done||f.value[0]!=c||f.value[1]!=c)return!1;f=e.next();return f.done||f.value[0]==c||4!=f.value[0].x||f.value[1]!=f.value[0]?!1:e.next().done}catch(g){return!1}}())return a;var b=function(c){this.j=new Map;if(c){c=
# _.Ld(c);for(var d;!(d=c.next()).done;)this.add(d.value)}this.size=this.j.size};b.prototype.add=function(c){c=0===c?0:c;this.j.set(c,c);this.size=this.j.size;return this};b.prototype.delete=function(c){c=this.j.delete(c);this.size=this.j.size;return c};b.prototype.clear=function(){this.j.clear();this.size=0};b.prototype.has=function(c){return this.j.has(c)};b.prototype.entries=function(){return this.j.entries()};b.prototype.values=function(){return this.j.values()};b.prototype.keys=b.prototype.values;
# b.prototype[Symbol.iterator]=b.prototype.values;b.prototype.forEach=function(c,d){var e=this;this.j.forEach(function(f){return c.call(d,f,f,e)})};return b});Vd("Array.from",function(a){return a?a:function(b,c,d){c=null!=c?c:function(h){return h};var e=[],f="undefined"!=typeof Symbol&&Symbol.iterator&&b[Symbol.iterator];if("function"==typeof f){b=f.call(b);for(var g=0;!(f=b.next()).done;)e.push(c.call(d,f.value,g++))}else for(f=b.length,g=0;g<f;g++)e.push(c.call(d,b[g],g));return e}});
# Vd("Array.prototype.values",function(a){return a?a:function(){return je(this,function(b,c){return c})}});var bba="function"==typeof Object.assign?Object.assign:function(a,b){for(var c=1;c<arguments.length;c++){var d=arguments[c];if(d)for(var e in d)ke(d,e)&&(a[e]=d[e])}return a};Vd("Object.assign",function(a){return a||bba});Vd("Array.prototype.findIndex",function(a){return a?a:function(b,c){return aba(this,b,c).q8}});
# Vd("Number.isNaN",function(a){return a?a:function(b){return"number"===typeof b&&isNaN(b)}});Vd("Object.entries",function(a){return a?a:function(b){var c=[],d;for(d in b)ke(b,d)&&c.push([d,b[d]]);return c}});Vd("Math.sign",function(a){return a?a:function(b){b=Number(b);return 0===b||isNaN(b)?b:0<b?1:-1}});
# Vd("String.fromCodePoint",function(a){return a?a:function(b){for(var c="",d=0;d<arguments.length;d++){var e=Number(arguments[d]);if(0>e||1114111<e||e!==Math.floor(e))throw new RangeError("o`"+e);65535>=e?c+=String.fromCharCode(e):(e-=65536,c+=String.fromCharCode(e>>>10&1023|55296),c+=String.fromCharCode(e&1023|56320))}return c}});Vd("Number.MAX_SAFE_INTEGER",function(){return 9007199254740991});
# Vd("Number.isFinite",function(a){return a?a:function(b){return"number"!==typeof b?!1:!isNaN(b)&&Infinity!==b&&-Infinity!==b}});Vd("Number.isInteger",function(a){return a?a:function(b){return Number.isFinite(b)?b===Math.floor(b):!1}});Vd("Array.prototype.fill",function(a){return a?a:function(b,c,d){var e=this.length||0;0>c&&(c=Math.max(0,e+c));if(null==d||d>e)d=e;d=Number(d);0>d&&(d=Math.max(0,e+d));for(c=Number(c||0);c<d;c++)this[c]=b;return this}});var le=function(a){return a?a:Array.prototype.fill};
# ...
# ]
# ,null,1]
# ,null,null,null,null,"aa|CBMicmh0dHBzOi8vd3d3LmJvb21saXZlLmluL2ZhY3QtY2hlY2svYmpwLWJlbmdhbC1zaGFyZXMtY2xpcHBlZC12aWRlby1vZi1tYW1hdGEtYmFuZXJqZWUtcmVjaXRpbmctaXNsYW1pYy12ZXJzZS0xMTY4NdIBAA"]
# ,[3,null,null,[13,[13,"CBMimgFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvZmFjdC1jaGVjay1lZGl0ZWQtY2xpcC1vZi1tYW1hdGEtcmVjaXRpbmctaXNsYW1pYy1wcmF5ZXJzLWxpbmtlZC10by1uZXRhamktZXZlbnQtY29udHJvdmVyc3ktMTc2MjI4NS0yMDIxLTAxLTI00gEA"]
# ,"Fact Check: Edited clip of Mamata reciting Islamic prayers linked to Netaji event controversy",null,[]
# ,null,"https://www.indiatoday.in/fact-check/story/fact-check-edited-clip-of-mamata-reciting-islamic-prayers-linked-to-netaji-event-controversy-1762285-2021-01-24",null,[]
# ,null,[12,[12,"PublisherOfCBMimgFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvZmFjdC1jaGVjay1lZGl0ZWQtY2xpcC1vZi1tYW1hdGEtcmVjaXRpbmctaXNsYW1pYy1wcmF5ZXJzLWxpbmtlZC10by1uZXRhamktZXZlbnQtY29udHJvdmVyc3ktMTc2MjI4NS0yMDIxLTAxLTI00gEA"]
# ,"India Today",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ]
# ,[]
# ,null,null,null,null,null,null,null,null,[]
# ,null,[]
# ,null,null,null,null,null,[]
# ,null,[]
# ,[]
# ,[]
# ,null,null,null,[null,[["Go to India Today","publications/CAAqBwgKMKLe3Aow_MTOAQ",[null,null,null,null,null,"link"]
# ,0,null,null,null,null,null,null,null,null,null,null,false]
# ]
# ]
# ,null,"https://www.indiatoday.in/fact-check/story/fact-check-edited-clip-of-mamata-reciting-islamic-prayers-linked-to-netaji-event-controversy-1762285-2021-01-24",null,null,"...",[[null,null,null,null,"fact_check:-286671238",7,141,null,null,null,null,null,null,null,null,2]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CBMimgFodHRwczovL3d3dy5pbmRpYXRvZGF5LmluL2ZhY3QtY2hlY2svc3RvcnkvZmFjdC1jaGVjay1lZGl0ZWQtY2xpcC1vZi1tYW1hdGEtcmVjaXRpbmctaXNsYW1pYy1wcmF5ZXJzLWxpbmtlZC10by1uZXRhamktZXZlbnQtY29udHJvdmVyc3ktMTc2MjI4NS0yMDIxLTAxLTI00gEA"]
# ,[3,null,null,[13,[13,"CBMikAFodHRwczovL3d3dy5ib29tbGl2ZS5pbi9mYWN0LWNoZWNrL2Zhcm1lcnMtcHJvdGVzdC1kZWxoaS1ib3JkZXJzLXRyYWN0b3ItcmFsbHktcmVwdWJsaWMtZGF5LXBhcmFkZS1qYW51YXJ5LTI2LXZpcmFsLXZpZGVvLWNocmlzdG1hcy1wYXJhZGUtMTE1OTfSAQA"]
# ,"Christmas Procession In Germany Viral As Farmers Rehearsing For R-Day",null,[]
# ,null,"https://www.boomlive.in/fact-check/farmers-protest-delhi-borders-tractor-rally-republic-day-parade-january-26-viral-video-christmas-parade-11597",null,[]
# ,null,[12,[12,"PublisherOfCBMikAFodHRwczovL3d3dy5ib29tbGl2ZS5pbi9mYWN0LWNoZWNrL2Zhcm1lcnMtcHJvdGVzdC1kZWxoaS1ib3JkZXJzLXRyYWN0b3ItcmFsbHktcmVwdWJsaWMtZGF5LXBhcmFkZS1qYW51YXJ5LTI2LXZpcmFsLXZpZGVvLWNocmlzdG1hcy1wYXJhZGUtMTE1OTfSAQA"]
# ,"BOOM",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ]
# ,[]
# ,null,null,null,null,null,null,null,null,[]
# ,null,[]
# ,null,null,null,null,null,[]
# ,null,[]
# ,[]
# ,[]
# ,null,null,null,[null,[["Go to BOOM","publications/CAAqBwgKMIP5jAsw6IKeAw",[null,null,null,null,null,"link"]
# ,0,null,null,null,null,null,null,null,null,null,null,false]
# ]
# ]
# ,null,"https://www.boomlive.in/fact-check/farmers-protest-delhi-borders-tractor-rally-republic-day-parade-january-26-viral-video-christmas-parade-11597",null,null,"...",[[null,null,null,null,"fact_check:-286671238",7,141,null,null,null,null,null,null,null,null,2]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CBMikAFodHRwczovL3d3dy5ib29tbGl2ZS5pbi9mYWN0LWNoZWNrL2Zhcm1lcnMtcHJvdGVzdC1kZWxoaS1ib3JkZXJzLXRyYWN0b3ItcmFsbHktcmVwdWJsaWMtZGF5LXBhcmFkZS1qYW51YXJ5LTI2LXZpcmFsLXZpZGVvLWNocmlzdG1hcy1wYXJhZGUtMTE1OTfSAQA"]
# ,[3,null,null,[13,[13,"CBMiZ2h0dHBzOi8vZmFjdGNoZWNrLmFmcC5jb20vdmlkZW8taGFzLWNpcmN1bGF0ZWQtb25saW5lLWZlYnJ1YXJ5LTIwMjAtYW5kLXNob3dzLXRyYWN0b3Itc3R1bnQtY29tcGV0aXRpb27SAQA"]
# ,"This video has circulated online since February 2020 and shows a tractor stunt competition",null,[]
# ,null,"https://factcheck.afp.com/video-has-circulated-online-february-2020-and-shows-tractor-stunt-competition",null,[]
# ,null,[12,[12,"PublisherOfCBMiZ2h0dHBzOi8vZmFjdGNoZWNrLmFmcC5jb20vdmlkZW8taGFzLWNpcmN1bGF0ZWQtb25saW5lLWZlYnJ1YXJ5LTIwMjAtYW5kLXNob3dzLXRyYWN0b3Itc3R1bnQtY29tcGV0aXRpb27SAQA"]
# ,"AFP Factcheck",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ]
# ,[]
# ,null,null,null,null,null,null,null,null,[]
# ,null,[]
# ,null,null,null,null,null,[]
# ,null,[]
# ,[]
# ,[]
# ,null,null,null,[null,[["Go to AFP Factcheck","publications/CAAqLQgKIidDQklTRndnTWFoTUtFV1poWTNSamFHVmpheTVoWm5BdVkyOXRLQUFQAQ",[null,null,null,null,null,"link"]
# ,0,null,null,null,null,null,null,null,null,null,null,false]
# ]
# ]
# ,null,"https://factcheck.afp.com/video-has-circulated-online-february-2020-and-shows-tractor-stunt-competition",null,null,"...",[[null,null,null,null,"fact_check:-286671238",7,141,null,null,null,null,null,null,null,null,2]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CBMiZ2h0dHBzOi8vZmFjdGNoZWNrLmFmcC5jb20vdmlkZW8taGFzLWNpcmN1bGF0ZWQtb25saW5lLWZlYnJ1YXJ5LTIwMjAtYW5kLXNob3dzLXRyYWN0b3Itc3R1bnQtY29tcGV0aXRpb27SAQA"]
# ,[3,null,null,[13,[13,"CBMiZ2h0dHBzOi8vd3d3LmFsdG5ld3MuaW4vZmFybWVyLXByb3Rlc3QtdHJhY3Rvci1wYXJhZGUtcmVwdWJsaWMtZGF5LWlyZWxhbmQtY2hyaXN0bWFzLXBhcmFkZS12aWRlby1mYWxzZS_SAQA"]
# ,"Video from Germany aired by Zee News as farmers preparing for 'war' with tractors in India",null,[]
# ,null,"https://www.altnews.in/farmer-protest-tractor-parade-republic-day-ireland-christmas-parade-video-false/",null,[]
# ,null,[12,[12,"PublisherOfCBMiZ2h0dHBzOi8vd3d3LmFsdG5ld3MuaW4vZmFybWVyLXByb3Rlc3QtdHJhY3Rvci1wYXJhZGUtcmVwdWJsaWMtZGF5LWlyZWxhbmQtY2hyaXN0bWFzLXBhcmFkZS12aWRlby1mYWxzZS_SAQA"]
# ,"Alt News",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ]
# ,[]
# ,null,null,null,null,null,null,null,null,[]
# ,null,[]
# ,null,null,null,null,null,[]
# ,null,[]
# ,[]
# ,[]
# ,null,null,null,[null,[["Go to Alt News","publications/CAAqJAgKIh5DQklTRUFnTWFnd0tDbUZzZEc1bGQzTXVhVzRvQUFQAQ",[null,null,null,null,null,"link"]
# ,0,null,null,null,null,null,null,null,null,null,null,false]
# ]
# ]
# ,null,"https://www.altnews.in/farmer-protest-tractor-parade-republic-day-ireland-christmas-parade-video-false/",null,null,"_KAaEBCAESDkdvIHRvIEFsdCBOZXdzGlEIAhI2Q0FBcUpBZ0tJaDVEUWtsVFJVRm5UV0ZuZDB0RGJVWnpaRWMxYkdRelRYVmhWelJ2UVVGUUFRGghBbHQgTmV3cyIHIzE4NWFiYzgAQAJCOhI2Q0FBcUpBZ0tJaDVEUWtsVFJVRm5UV0ZuZDB0RGJVWnpaRWMxYkdRelRYVmhWelJ2UVVGUUFRYAI",[[null,null,null,null,"fact_check:-286671238",7,141,null,null,null,null,null,null,null,null,2]
# ]
# ,null,1]
# ,null,null,null,null,"aa|CBMiZ2h0dHBzOi8vd3d3LmFsdG5ld3MuaW4vZmFybWVyLXByb3Rlc3QtdHJhY3Rvci1wYXJhZGUtcmVwdWJsaWMtZGF5LWlyZWxhbmQtY2hyaXN0bWFzLXBhcmFkZS12aWRlby1mYWxzZS_SAQA"]
# ]
# ,null,null,null,null,null,null,null,"",null,null,null,3,null,null,null,null,false,null,[]
# ,null,null,null,null,null,null,"ui|2aa288d4-b32d-40b3-b283-7a0693651dfa",[[[null,null,null,null,"fact_check:-286671238",7,141]
# ]
# ,47]
# ]
# ,null,null,null,null,null,"aa|ui|c7600937-a18f-4b49-ac6f-106479825c59"]
# ,[2,null,[24,[24,"ui|fab8d078-08df-4045-bd29-8455c4904e94"]
# ,"In the news",[[1,[33,[33,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNREkzTTNOMGFCSUNaVzRvQUFQAQ"]
# ,"Shikhar Dhawan",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#1e8e3e","#ffffff",true]
# ,null,"en-GB",[["https://lh6.googleusercontent.com/proxy/5eSMvBQ9Enqanxr4ZWmQaX5g-j3_mTZd31aXl4q9WIvHoQFkeh0Mc8YkfMMEaHrcjAWDMK8dfiUkNxd3r8gkYHic0C45TvpUbbUI2EHNGuXYoRVbRtdjnCxG95ojAfCAARlwyg2f7UqFDBHgJoJ3jjzp3uhcYgeY1HGvArp-iDg-H-I",null,null,null,"\u003ca target\u003d\"_blank\" href\u003d\"https://commons.wikimedia.org/wiki/File:SHIKHAR_DHAWAN_(16005494418).jpg\"\u003eBy NAPARAZZI (SHIKHAR DHAWAN) [CC BY-SA 2.0 (https://creativecommons.org/licenses/by-sa/2.0)], via Wikimedia Commons\u003c/a\u003e"]
# ,null,1,2,["#1e8e3e","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNREkzTTNOMGFCSUNaVzRvQUFQAQ",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"Shikhar Dhawan"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqJAgKIh5DQkFTRUFvS0wyMHZNREkzTTNOMGFCSUNaVzRvQUFQAQ"]
# ,[1,[33,[33,"CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE55YXpBU0FtVnVLQUFQAQ"]
# ,"India",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#8430c3","#ffffff",true]
# ,null,"en-GB",[["https://lh3.googleusercontent.com/proxy/QghSAsctZbwN0l6SwrXh0q6McqqRNmgMm9CVcjKjSCxHWkTL8tlACy_Cdko_4NZ5G0sXHnRTKk2POz2B7ZYh-9Sbimyq8nd44R2DuI_JDI3XryxyYilmWp3odFMVL0ON4PhBnsfMTfh5Elx99y2TQqWev4qh3viPbcsRg2ByaHPXosI"]
# ,null,1,2,["#8430c3","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE55YXpBU0FtVnVLQUFQAQ",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"India"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqIQgKIhtDQkFTRGdvSUwyMHZNRE55YXpBU0FtVnVLQUFQAQ"]
# ,[1,[33,[33,"CAAqIggKIhxDQkFTRHdvSkwyMHZNREl4WHpReUVnSmxiaWdBUAE"]
# ,"Election Commission of India",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#0a9697","#ffffff",true]
# ,null,"en-GB",[null,"E\u200cC",null,2,["#0a9697","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqIggKIhxDQkFTRHdvSkwyMHZNREl4WHpReUVnSmxiaWdBUAE",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"Election Commission of India"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqIggKIhxDQkFTRHdvSkwyMHZNREl4WHpReUVnSmxiaWdBUAE"]
# ,[1,[33,[33,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNR28zYm1Kd1p4SUNaVzRvQUFQAQ"]
# ,"Balwant Singh Rajoana",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#df3093","#ffffff",true]
# ,null,"en-GB",[null,"B\u200cS",null,2,["#df3093","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNR28zYm1Kd1p4SUNaVzRvQUFQAQ",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"Balwant Singh Rajoana"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqJAgKIh5DQkFTRUFvS0wyMHZNR28zYm1Kd1p4SUNaVzRvQUFQAQ"]
# ,[1,[33,[33,"CAAqIggKIhxDQkFTRHdvSkwyMHZNRGRrWkhnMEVnSmxiaWdBUAE"]
# ,"Union budget of India",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#df3093","#ffffff",true]
# ,null,"en-GB",[null,"U\u200cb",null,2,["#df3093","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqIggKIhxDQkFTRHdvSkwyMHZNRGRrWkhnMEVnSmxiaWdBUAE",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"Union budget of India"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqIggKIhxDQkFTRHdvSkwyMHZNRGRrWkhnMEVnSmxiaWdBUAE"]
# ,[1,[33,[33,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNRE4zWmpVNWN4SUNaVzRvQUFQAQ"]
# ,"Arnab Goswami",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#ea4335","#ffffff",true]
# ,null,"en-GB",[["https://lh5.googleusercontent.com/proxy/_LSpselzRsZWk0JmI5HtEiQ-fw1y2nnREycwEKhuoakmKz1u67UT5ZX23GY60L8H3ArEDMs8BgE3GHPucBUqwlYlMPxFgRee-h59iykakuN3a_zAhAKF-Ai4Ha_EUQ5ji2a8IGMRYGcRkMhdw79CK_QmV8BlvqSwu8TS3QJLCaNO9Dk",null,null,null,"\u003ca target\u003d\"_blank\" href\u003d\"https://commons.wikimedia.org/wiki/File:Arnab_Goswami_Times_Now.jpg\"\u003eBy Abhinav619 [CC BY-SA 3.0 (https://creativecommons.org/licenses/by-sa/3.0)], from Wikimedia Commons\u003c/a\u003e"]
# ,null,1,2,["#ea4335","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNRE4zWmpVNWN4SUNaVzRvQUFQAQ",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"Arnab Goswami"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqJAgKIh5DQkFTRUFvS0wyMHZNRE4zWmpVNWN4SUNaVzRvQUFQAQ"]
# ,[1,[33,[33,"CAAqIggKIhxDQkFTRHdvSkwyMHZNRGMzZG13ekVnSmxiaWdBUAE"]
# ,"Beant Singh",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#1bb3c8","#ffffff",true]
# ,null,"en-GB",[null,"B\u200cS",null,2,["#1bb3c8","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqIggKIhxDQkFTRHdvSkwyMHZNRGMzZG13ekVnSmxiaWdBUAE",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"Beant Singh"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqIggKIhxDQkFTRHdvSkwyMHZNRGMzZG13ekVnSmxiaWdBUAE"]
# ,[1,[33,[33,"CAAqIAgKIhpDQkFTRFFvSEwyMHZNSGw1YUJJQ1pXNG9BQVAB"]
# ,"Andhra Pradesh",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#fa7b17","#ffffff",true]
# ,null,"en-GB",[["https://lh5.googleusercontent.com/proxy/torOyfynPgPAXqf5q4YBOb767KKsmRahTI5-huRN-nFxsS6Xhe2vln-IrywMZ84tKhpoVpicRDvrPfvy_6mT8HTEEpsvfWm-ll6Zg_ZJrJal1LuuR40Vxe5a9UxAFH01g_zGTFe5KuW2ox7xyEGF_BL-vIvl0YN7_u0KYxV1BzuabZ0"]
# ,null,1,2,["#fa7b17","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqIAgKIhpDQkFTRFFvSEwyMHZNSGw1YUJJQ1pXNG9BQVAB",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"Andhra Pradesh"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqIAgKIhpDQkFTRFFvSEwyMHZNSGw1YUJJQ1pXNG9BQVAB"]
# ,[1,[33,[33,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNR2RtWm1oMmRCSUNaVzRvQUFQAQ"]
# ,"National Voters' Day",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#df3093","#ffffff",true]
# ,null,"en-GB",[["https://lh6.googleusercontent.com/proxy/HP7HIKGwGx9InPl2PnyhqdqTXO6d4GrIjrBrQPQ-_nUMX933nu48lBJRQK8dpvnMVqcRBaWNEZufijncSOPqDAfikTA6bF2zPueecL0CCgAYo9Ge4DfEeyZLVgBC3mixVyf4MDdU7lzDLx4lN4Tb9awzD53xKvYV9ysvPpdfn-eYqHA"]
# ,null,1,2,["#df3093","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqJAgKIh5DQkFTRUFvS0wyMHZNR2RtWm1oMmRCSUNaVzRvQUFQAQ",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"National Voters' Day"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqJAgKIh5DQkFTRUFvS0wyMHZNR2RtWm1oMmRCSUNaVzRvQUFQAQ"]
# ,[1,[33,[33,"CAAqIggKIhxDQkFTRHdvSkwyMHZNR1F3TlhjekVnSmxiaWdBUAE"]
# ,"China",null,[]
# ,null,null,null,null,null,null,null,null,[]
# ,["#1bb3c8","#ffffff",true]
# ,null,"en-GB",[["https://lh4.googleusercontent.com/proxy/e8JTy_2O5eFnCXcl-Fc3wgajCT8Gql3UEnG5Pm8UO7ak8EAP7O9VPSys0bD8LW9wCWN7GEzD2lkIrS_0oUJ3DtxGmqmqKTVWOI2lWIu2YtSjYs4l1o8ZCYjIL-_Fb9CO8bDQ39N66pmK5O76eteM6HGYpockvcztbaNff-1Tdc7Kshs"]
# ,null,1,2,["#1bb3c8","#ffffff"]
# ]
# ,null,[]
# ,1,null,null,null,null,null,null,null,false,null,[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ,[null,"CAAqIggKIhxDQkFTRHdvSkwyMHZNR1F3TlhjekVnSmxiaWdBUAE",null,null,null,null,null,null,null,null,null,2]
# ,null,[null,null,null,null,null,null,null,[null,"China"]
# ]
# ]
# ,3]
# ]
# ,null,null,null,null,null,null,"aa|CAAqIggKIhxDQkFTRHdvSkwyMHZNR1F3TlhjekVnSmxiaWdBUAE"]
# ]
# ,null,null,null,null,null,null,null,"",null,null,null,3,2,null,null,null,false,null,[]
# ,null,null,null,null,null,null,"ui|2471e94b-998a-434e-a311-ccd83ae7c131",[[[null,null,null,null,"in_the_news:-743369533",7,141]
# ]
# ,47]
# ]
# ,null,null,null,null,null,"aa|ui|fab8d078-08df-4045-bd29-8455c4904e94"]
# ]
# ,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,[]
# ,null,null,null,null,null,null,"ui|e7ee7f29-1cc2-4bca-bb5f-8eecda49731a",[[[null,null,null,null,null,null,141]
# ]
# ]
# ]
# ,null,null,null,null,null,"aa|ui|7a41d346-b9a3-469e-94c9-571ca8bac3c7"]
# ,null,2]
# , sideChannel: {}});</script><script id="wiz_jd" nonce="V1E+fRepipsOFwM6k5TCZA">if (window['_wjdc']) {const wjd = {}; window['_wjdc'](wjd); delete window['_wjdc'];}</script><script aria-hidden="true" nonce="V1E+fRepipsOFwM6k5TCZA">window.wiz_progress&&window.wiz_progress(); window.stopScanForCss&&window.stopScanForCss(); ccTick('bl');</script></body></html>

# %%
sou
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-46-466fb8026c94> in <module>
#       2 for article in articles:
#       3     s = article
# ----> 4     a = s.select("h3")[1]
#       5     print(a)
#
# IndexError: list index out of range
